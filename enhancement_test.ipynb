# %%
# ✅ Load functions
from keyword_matcher import extract_keywords, compute_keyword_match
from parsing_module import extract_text_pdfplumber, split_resume_into_sections
from llm_enhancer import enhance_summary_with_gpt, enhance_skills_with_gpt, enhance_experience_job, build_experience_prompt
from experience_splitter import split_experience_section, parse_job_entry

# %%
# ✅ Load and parse resume PDF
resume_text = extract_text_pdfplumber("docs/sample_resume.pdf")
sections = split_resume_into_sections(resume_text)
summary_text = sections.get("summary", "")
full_resume_text = resume_text.lower()  # for keyword matching

# %%
# ✅ Sample job description (paste your real one if needed)
job_posting = """
People Data Analyst:

As a People Data Analyst, you will play a critical role in CAVA’s People & Culture function, specifically within the Total Rewards team. This role is responsible for producing regular reporting and data analysis, key in supporting strategic decision-making across People & Culture, while also collaborating with cross-functional teams across the organization. Your insights will help drive equitable, data-driven, and competitive strategies to attract and retain top talent. This role will provide data backed recommendations to help drive workforce strategy and support industry best practices.



What You’ll Do: 

Develop Periodic Reporting: Assist in creating and enhancing daily reporting to support various business areas.
Audit our People Data: Transform raw data so that it can be used in creating reports, maintaining reports, and summarizing results associated with our audits.
Interpret our People Data: Identify trends in data, comparing to both internal and external benchmarks.
Collaborate with Talent Acquisition & HR: Partner with recruiting and HR teams to merge data from outside of our HRIS systems to provide new insights and assist in creating new metrics.
Assist in Cross-Functional Analysis: Develop expertise in the organization’s people data and how it can be leveraged across other areas of the organization.
Maintain People Analytics Dashboards: Assist in dashboard maintenance and development.
Measure and Track Impact: Identify dates associated with initiatives to inform the business of the results of initiatives.


The Qualifications:

Bachelor’s degree in Human Resources, Business, Finance, Statistics, or a related field.
2+ years of experience in HR analytics, or data analysis in a corporate environment.
Proficiency in Excel (advanced), HRIS systems, and data visualization tools (e.g., Tableau, Power BI).
Experience working with SQL, Python, or another programming language preferred.
"""

# ✅ Compute match result and extract missing keywords
match_result = compute_keyword_match(full_resume_text, job_posting)
missing_keywords = match_result["missing_keywords"]
print("🧩 Missing Keywords:", missing_keywords)
# Out:
# 🧩 Missing Keywords: ['acquisition', 'audit', 'benchmark', 'collaborate', 'competitive', 'corporate', 'degree', 'hris', 'maintain', 'maintenance', 'recruiting', 'strategy', 'talent', 'tool']

# %%
# ✅ Run Summary Enhancement
print("\n🧠 Original Summary:\n", summary_text)

enhanced_summary = enhance_summary_with_gpt(summary_text, missing_keywords)

print("\n✨ Enhanced Summary:\n", enhanced_summary)
# Out:
# 🧠 Original Summary:
#  Federal Data Analyst with 4+ years in human capital analytics, data-driven decision-making, and workforce planning. Skilled
# in SQL, Python, Tableau, and Power BI, with a track record of optimizing HR processes through data analysis, reporting
# automation, and visualization.
#
# ✨ Enhanced Summary:
#  Corporate Federal Data Analyst with a degree and 4+ years of experience in human capital analytics, talent acquisition, and workforce strategy. Proficient in SQL, Python, HRIS, Tableau, and Power BI. Demonstrated ability to collaborate on audits, maintain benchmark standards, and enhance competitive recruiting through data-driven decision-making, reporting automation, and visualization tools.

# %%
# ✅ Run Skills Enhancement
skills_text = sections.get("skills", "")
print("\n📋 Original Skills:\n", skills_text)

enhanced_skills = enhance_skills_with_gpt(skills_text, missing_keywords)

print("\n🚀 Enhanced Skills:\n", enhanced_skills)
# Out:
# 📋 Original Skills:
#  ● Data Analytics & Visualization: SQL · Python · Tableau · Power BI · Advanced Excel · Advanced MS Office Suite
# ● Human Capital & Workforce Analytics: HR Metrics · Hiring Pipeline Analytics · Employee Retention Analysis ·
# Workforce Planning
# ● Data Management & Integrity: Data Mining · Data Cleaning · Quality Assurance · Database Management · Process
# Optimization
# ● Reporting & Decision Support: Ad Hoc Reporting · Dashboard Development · Executive Presentations · Stakeholder
# Communication
# ● Process Automation & Compliance: Workflow Automation · Data Privacy & Security · Federal HR Policy Compliance
# ● Strategic Insights & Decision Making: Data-Driven Recommendations · Trend Analysis · Large Dataset Processing ·
# Proactive Problem-Solving
#
# 🚀 Enhanced Skills:
#  ---
# ● Data Analytics & Visualization Tools: SQL · Python · Tableau · Power BI · Advanced Excel · Advanced MS Office Suite · HRIS
# ● Talent Acquisition & Workforce Strategy: HR Metrics · Hiring Pipeline Analytics · Employee Retention Analysis · Workforce Planning · Recruiting · Benchmarking
# ● Data Management & Maintenance: Data Mining · Data Cleaning · Quality Assurance · Database Management · Process Optimization · Audit
# ● Reporting & Corporate Decision Support: Ad Hoc Reporting · Dashboard Development · Executive Presentations · Stakeholder Communication · Competitive Analysis
# ● Process Automation & Compliance Strategy: Workflow Automation · Data Privacy & Security · Federal HR Policy Compliance · HRIS Maintenance
# ● Strategic Insights & Decision Making Tools: Data-Driven Recommendations · Trend Analysis · Large Dataset Processing · Proactive Problem-Solving · Acquisition Strategy
# ---

# %%
from llm_enhancer import enhance_experience_job, build_experience_prompt

# Grab one parsed job entry (assuming you already split it earlier)
from experience_splitter import split_experience_section, parse_job_entry

# Pull and parse the experience section
experience_text = sections.get("experience", "")
experience_chunks = split_experience_section(experience_text)

# Choose one job to test
sample_job_chunk = experience_chunks[0]
parsed_job = parse_job_entry(sample_job_chunk)

# Enhance the parsed job
enhanced_job = enhance_experience_job(parsed_job, missing_keywords, job_posting)

# Print result
from pprint import pprint
print("\n✨ Enhanced Experience Entry:\n")
pprint(enhanced_job)
# Out:
# ✨ Enhanced Experience Entry:
#
# {'bullets': ['Leveraged data mining to extract critical human capital '
#              'information, supporting strategic decision-making and talent '
#              'acquisition across divisions, enhancing workforce planning '
#              'through comprehensive data analysis.',
#              'Designed an Excel VBA-based incentive tracking tool, integrating '
#              'engagement analysis to assess award effectiveness, automating '
#              'validation checks and improving data accuracy by 85%, supporting '
#              'data-driven and competitive strategies.',
#              'Developed a Python-based payroll tracking system, integrating '
#              'multiple fund sources and leveraging SQL for data extraction, '
#              'reducing reconciliation time by ~2 hours/month, improving '
#              'payroll forecasting accuracy and aiding in budget allocation.',
#              'Optimized SharePoint-based data management processes, enhancing '
#              'workflow automation and document version control for financial '
#              'reporting, ensuring compliance with federal regulations and data '
#              'privacy laws.',
#              'Conducted financial forecasting and variance analysis for a '
#              '$165M payroll budget, leading to actionable FTE adjustments and '
#              'full-year payroll projections, optimizing workforce planning and '
#              'supporting industry best practices.',
#              'Collaborated with data science teams to optimize AI algorithms, '
#              'reducing budget forecasting errors by 15%, improving overall '
#              'accuracy in financial planning, and maintaining HRIS systems.'],
#  'company': 'Substance Abuse and Mental Health Administration, Department of '
#             'HHS',
#  'date_range': "Dec '23 - Mar '25",
#  'title': 'Budget Analyst'}

# %%
# Parse and enhance each job entry
enhanced_jobs = []
for chunk in experience_chunks:
    parsed_job = parse_job_entry(chunk)
    enhanced_job = enhance_experience_job(parsed_job, missing_keywords, job_posting)
    enhanced_jobs.append(enhanced_job)

# Preview results
from pprint import pprint
for job in enhanced_jobs:
    print("\n📌", job["title"], "at", job["company"], job["date_range"])
    pprint(job["bullets"])
# Out:
# 📌 Budget Analyst at Substance Abuse and Mental Health Administration, Department of HHS Dec '23 - Mar '25
# ['Leveraged data mining to extract critical human capital information, '
#  'supporting strategic decision-making and talent acquisition strategies '
#  'across various divisions.',
#  'Engineered an Excel VBA and Python-based system for incentive tracking and '
#  'payroll management, integrating HRIS data and automating workflows to '
#  'enhance data accuracy by 85% and reduce reconciliation time by ~2 '
#  'hours/month.',
#  'Collaborated with cross-functional teams to optimize AI algorithms and '
#  'decision pathways, resulting in a 30% reduction in processing time for '
#  'budget approvals and a 15% decrease in budget forecasting errors.',
#  'Designed SharePoint-based data management processes, maintaining workflow '
#  'automation and document version control for financial reporting, ensuring '
#  'compliance with federal regulations and data privacy laws.',
#  'Conducted financial forecasting and variance analysis for a $165M payroll '
#  'budget, providing data-backed recommendations for FTE adjustments and '
#  'full-year payroll projections, optimizing workforce planning and budget '
#  'allocation.',
#  'Developed and maintained Power BI dashboards for real-time insights into '
#  'budget utilization, payroll trends, and workforce analytics, driving '
#  'data-driven decision-making and competitive strategies to attract and retain '
#  'top talent.']
#
# 📌 Budget Analyst at CRI – Department of the Interior Mar '21 - Dec '23
# ['Devised and executed data quality improvement strategies, boosting financial '
#  'data accuracy by 20% and driving continuous process enhancements through '
#  'pattern and trend analysis.',
#  'Fostered cross-functional collaboration with IT and Finance teams, enhancing '
#  'financial database integration and analytics workflows to support strategic '
#  'corporate decision-making.',
#  'Streamlined reporting processes through the development of workflow '
#  'automation solutions using Python and SQL, reducing manual work by 15% and '
#  'aiding in the maintenance of People Analytics Dashboards.',
#  'Established standardized annotation guidelines for financial reporting, '
#  'ensuring consistency in data analysis and AI training datasets, and aiding '
#  'in the audit of People Data.',
#  'Collaborated with Talent Acquisition and HR teams, leveraging data from '
#  'outside HRIS systems to provide new insights and assist in creating new '
#  'metrics.',
#  'Utilized advanced Excel, HRIS systems, and data visualization tools to '
#  'interpret People Data, identify trends, and compare to internal and external '
#  'benchmarks.']
#
# 📌 Accounting Analyst at Cresa Dec '20 - Mar '21
# ['Collaborated with corporate teams to analyze financial data, driving '
#  'strategic decision-making through clear, data-driven insights.',
#  'Conducted rigorous audits and reconciliations of financial data, maintaining '
#  'accuracy and integrity in all reports.',
#  'Utilized advanced Excel and data visualization tools to present findings on '
#  'expense trends and revenue forecasts.',
#  'Supported talent acquisition strategy by providing data-backed '
#  'recommendations on budget allocations and marketing expenditures.',
#  'Benchmarked internal financial data against industry standards to ensure '
#  'competitive positioning.',
#  'Assisted in the maintenance and development of data dashboards, enhancing '
#  "the organization's ability to track and measure impact."]
#
# 📌 Fund Accountant at FrontStream Aug '18 - Sep '20
# ['Streamlined financial reconciliation through SQL and VBA automation, '
#  'reducing manual workload by 250+ hours annually and driving data-backed '
#  'decision-making.',
#  'Managed and audited a portfolio of nonprofit donations, leveraging data '
#  'analysis for strategic fund distribution and maintaining financial '
#  'transparency.',
#  'Collaborated with cross-functional teams to design real-time financial '
#  'tracking dashboards, enhancing stakeholder transparency and supporting '
#  'corporate strategy.',
#  'Utilized HRIS systems and data visualization tools to maintain and enhance '
#  'financial tracking dashboards, aligning with industry benchmarks.',
#  'Leveraged data analysis to drive competitive strategies in fund '
#  'distribution, attracting and retaining key stakeholders.',
#  'Merged data from various sources to provide new insights, assisting in the '
#  'creation of new metrics and supporting talent acquisition efforts.']

# %%
def format_experience_section(jobs: list) -> str:
    """
    Formats a list of enhanced job dicts into a clean, copy-pasteable
    'Experience' section string with proper bullets and spacing.
    """
    lines = []

    for job in jobs:
        header = f"📌 {job['title']} at {job['company']} {job['date_range']}"
        lines.append(header)

        for bullet in job["bullets"]:
            lines.append(f"• {bullet.strip()}")

        lines.append("")  # Blank line between jobs

    return "\n".join(lines).strip()

formatted_experience = format_experience_section(enhanced_jobs)
print(formatted_experience)
# Out:
# 📌 Budget Analyst at Substance Abuse and Mental Health Administration, Department of HHS Dec '23 - Mar '25
# • Leveraged data mining to extract critical human capital information, supporting strategic decision-making and talent acquisition strategies across various divisions.
# • Engineered an Excel VBA and Python-based system for incentive tracking and payroll management, integrating HRIS data and automating workflows to enhance data accuracy by 85% and reduce reconciliation time by ~2 hours/month.
# • Collaborated with cross-functional teams to optimize AI algorithms and decision pathways, resulting in a 30% reduction in processing time for budget approvals and a 15% decrease in budget forecasting errors.
# • Designed SharePoint-based data management processes, maintaining workflow automation and document version control for financial reporting, ensuring compliance with federal regulations and data privacy laws.
# • Conducted financial forecasting and variance analysis for a $165M payroll budget, providing data-backed recommendations for FTE adjustments and full-year payroll projections, optimizing workforce planning and budget allocation.
# • Developed and maintained Power BI dashboards for real-time insights into budget utilization, payroll trends, and workforce analytics, driving data-driven decision-making and competitive strategies to attract and retain top talent.
#
# 📌 Budget Analyst at CRI – Department of the Interior Mar '21 - Dec '23
# • Devised and executed data quality improvement strategies, boosting financial data accuracy by 20% and driving continuous process enhancements through pattern and trend analysis.
# • Fostered cross-functional collaboration with IT and Finance teams, enhancing financial database integration and analytics workflows to support strategic corporate decision-making.
# • Streamlined reporting processes through the development of workflow automation solutions using Python and SQL, reducing manual work by 15% and aiding in the maintenance of People Analytics Dashboards.
# • Established standardized annotation guidelines for financial reporting, ensuring consistency in data analysis and AI training datasets, and aiding in the audit of People Data.
# • Collaborated with Talent Acquisition and HR teams, leveraging data from outside HRIS systems to provide new insights and assist in creating new metrics.
# • Utilized advanced Excel, HRIS systems, and data visualization tools to interpret People Data, identify trends, and compare to internal and external benchmarks.
#
# 📌 Accounting Analyst at Cresa Dec '20 - Mar '21
# • Collaborated with corporate teams to analyze financial data, driving strategic decision-making through clear, data-driven insights.
# • Conducted rigorous audits and reconciliations of financial data, maintaining accuracy and integrity in all reports.
# • Utilized advanced Excel and data visualization tools to present findings on expense trends and revenue forecasts.
# • Supported talent acquisition strategy by providing data-backed recommendations on budget allocations and marketing expenditures.
# • Benchmarked internal financial data against industry standards to ensure competitive positioning.
# • Assisted in the maintenance and development of data dashboards, enhancing the organization's ability to track and measure impact.
#
# 📌 Fund Accountant at FrontStream Aug '18 - Sep '20
# • Streamlined financial reconciliation through SQL and VBA automation, reducing manual workload by 250+ hours annually and driving data-backed decision-making.
# • Managed and audited a portfolio of nonprofit donations, leveraging data analysis for strategic fund distribution and maintaining financial transparency.
# • Collaborated with cross-functional teams to design real-time financial tracking dashboards, enhancing stakeholder transparency and supporting corporate strategy.
# • Utilized HRIS systems and data visualization tools to maintain and enhance financial tracking dashboards, aligning with industry benchmarks.
# • Leveraged data analysis to drive competitive strategies in fund distribution, attracting and retaining key stakeholders.
# • Merged data from various sources to provide new insights, assisting in the creation of new metrics and supporting talent acquisition efforts.
