# %%
from html_converter import convert_resume_to_html
from gpt_parser import parse_resume_with_gpt

# Load and convert your resume
html = convert_resume_to_html("docs/sample_resume.pdf")

# Preview the HTML if needed
print("=== HTML Preview ===")
print(html[:500])

# Parse it using GPT
parsed = parse_resume_with_gpt(html)

# Print the structured result
import pprint
pprint.pprint(parsed)
# Out:
# [INFO] Start to convert docs/sample_resume.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] [4/4] Creating pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] Terminated in 0.72s.
# === HTML Preview ===
# <p>Neal Iyer <br />Data Analyst | McLean, VA | 240-644-7960 | <a href="mailto:neal.iyer88@gmail.com">neal.iyer88@gmail.com</a> </p><p>Professional Summary </p><p></p><p>Federal Data Analyst with 4+ years in human capital analytics, data-driven decision-making, and workforce planning. Skilled </p><p>in SQL, Python, Tableau, and Power BI, with a track record of optimizing HR processes through data analysis, reporting </p><p>automation, and visualization. </p><p>Professional Skills </p><p></p><tabl
# [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# GPT RAW RESPONSE:
#  ```json
# {
# ...
